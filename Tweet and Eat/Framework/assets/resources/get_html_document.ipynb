# %%
import pandas as pd
from pprint import pprint

# %%
df = pd.read_csv("cities.csv")
html = df.to_html(border=1,justify="center")

# %%
print(html)
# Out:
# <table border="2" class="dataframe">
#   <thead>
#     <tr style="text-align: center;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Jiaojiang</td>
#       <td>28.68</td>
#       <td>121.44</td>
#       <td>73.00</td>
#       <td>73</td>
#       <td>84</td>
#       <td>9.06</td>
#       <td>CN</td>
#       <td>1598894576</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Punta Arenas</td>
#       <td>-53.15</td>
#       <td>-70.92</td>
#       <td>44.60</td>
#       <td>65</td>
#       <td>40</td>
#       <td>19.46</td>
#       <td>CL</td>
#       <td>1598894577</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...

# %%
text_file = open("data.html", "w")
text_file.write(html)
text_file.close()
